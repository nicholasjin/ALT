# %% [markdown]
# Prototyping our data acquisition pipeline

# %%
from bs4 import BeautifulSoup
import requests

# %%
target_website = "https://azurlane.koumakan.jp/List_of_Ships_by_Stats"
result = requests.get(target_website)
assert result.status_code == 200

# %%
result
# Out:
# <Response [200]>

# %%
# result.content
soup = BeautifulSoup(result.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en-GB">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Ships by Stats - Azur Lane Wiki
#   </title>
#   <script>
# ...

# %%
tables = soup.find("table")
tables
# Out:
# <table class="azltable toggle-right mw-collapsible mw-collapsed" style="width:248px">
# <caption>Legend
# </caption>
# <tbody><tr>
# <th>Icon
# </th>
# <th>Definition
# </th></tr>
# <tr>
# <th><img alt="Health" data-file-height="62" data-file-width="62" decoding="async" height="25" loading="lazy" src="/w/images/thumb/8/8b/Duration.png/25px-Duration.png" srcset="/w/images/thumb/8/8b/Duration.png/38px-Duration.png 1.5x, /w/images/thumb/8/8b/Duration.png/50px-Duration.png 2x" title="Health" width="25"/>
# </th>
# <td>Health
# </td></tr>
# <tr>
# <th><img alt="Firepower" data-file-height="62" data-file-width="62" decoding="async" height="25" loading="lazy" src="/w/images/thumb/d/d5/Firepower.png/25px-Firepower.png" srcset="/w/images/thumb/d/d5/Firepower.png/38px-Firepower.png 1.5x, /w/images/thumb/d/d5/Firepower.png/50px-Firepower.png 2x" title="Firepower" width="25"/>
# </th>
# <td>Firepower
# </td></tr>
# <tr>
# ...

# %%
tables
# Out:
# <table class="azltable toggle-right mw-collapsible mw-collapsed" style="width:248px">
# <caption>Legend
# </caption>
# <tbody><tr>
# <th>Icon
# </th>
# <th>Definition
# </th></tr>
# <tr>
# <th><img alt="Health" data-file-height="62" data-file-width="62" decoding="async" height="25" loading="lazy" src="/w/images/thumb/8/8b/Duration.png/25px-Duration.png" srcset="/w/images/thumb/8/8b/Duration.png/38px-Duration.png 1.5x, /w/images/thumb/8/8b/Duration.png/50px-Duration.png 2x" title="Health" width="25"/>
# </th>
# <td>Health
# </td></tr>
# <tr>
# <th><img alt="Firepower" data-file-height="62" data-file-width="62" decoding="async" height="25" loading="lazy" src="/w/images/thumb/d/d5/Firepower.png/25px-Firepower.png" srcset="/w/images/thumb/d/d5/Firepower.png/38px-Firepower.png 1.5x, /w/images/thumb/d/d5/Firepower.png/50px-Firepower.png 2x" title="Firepower" width="25"/>
# </th>
# <td>Firepower
# </td></tr>
# <tr>
# ...
